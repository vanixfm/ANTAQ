# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_atrac = pd.read_csv('/content/drive/MyDrive/2022/2022Atracacao.txt', sep=';', encoding='utf-8', low_memory=False)
df_tempos = pd.read_csv('/content/drive/MyDrive/2022/2022TemposAtracacao.txt', sep=';', encoding='utf-8', low_memory=False)
df_paralis = pd.read_csv('/content/drive/MyDrive/2022/2022TemposAtracacaoParalisacao.txt', sep=';', encoding='utf-8', low_memory=False)

print('---------------------------------------------------------------------------------------------------------------------------------')
num_linhas1 = len(df_atrac)
num_linhas2 = len(df_tempos)
num_linhas3 = len(df_paralis)

print(f"O arquivo contém {num_linhas1} linhas.")
print(f"O arquivo contém {num_linhas2} linhas.")
print(f"O arquivo contém {num_linhas3} linhas.")

print('---------------------------------------------------------------------------------------------------------------------------------')

print(df_atrac.columns)
print('---------------------------------------------------------------------------------------------------------------------------------')
print(df_tempos.columns)
print('---------------------------------------------------------------------------------------------------------------------------------')
print(df_paralis.columns)
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------
# O arquivo contém 85092 linhas.
# O arquivo contém 85092 linhas.
# O arquivo contém 106569 linhas.
# ---------------------------------------------------------------------------------------------------------------------------------
# Index(['IDAtracacao', 'CDTUP', 'IDBerco', 'Berço', 'Porto Atracação',
#        'Coordenadas', 'Apelido Instalação Portuária', 'Complexo Portuário',
#        'Tipo da Autoridade Portuária', 'Data Atracação', 'Data Chegada',
#        'Data Desatracação', 'Data Início Operação', 'Data Término Operação',
#        'Ano', 'Mes', 'Tipo de Operação', 'Tipo de Navegação da Atracação',
#        'Nacionalidade do Armador', 'FlagMCOperacaoAtracacao', 'Terminal',
#        'Município', 'UF', 'SGUF', 'Região Geográfica', 'Região Hidrográfica',
#        'Instalação Portuária em Rio', 'Nº da Capitania', 'Nº do IMO'],
#       dtype='object')
# ---------------------------------------------------------------------------------------------------------------------------------
# Index(['IDAtracacao', 'TEsperaAtracacao', 'TEsperaInicioOp', 'TOperacao',
#        'TEsperaDesatracacao', 'TAtracado', 'TEstadia'],
#       dtype='object')
# ---------------------------------------------------------------------------------------------------------------------------------
# Index(['IDTemposDescontos', 'IDAtracacao', 'DescricaoTempoDesconto',
#        'DTInicio', 'DTTermino'],
#       dtype='object')

# %%
colunas = ['IDAtracacao', 'Porto Atracação', 'Data Atracação', 'Data Chegada', 'Data Desatracação',
           'Data Início Operação', 'Data Término Operação', 'Ano', 'Mes', 'Tipo de Operação',
           'Município', 'UF', 'Região Geográfica', 'Região Hidrográfica','Tipo da Autoridade Portuária']

df_atrac = pd.read_csv('/content/drive/MyDrive/2022/2022Atracacao.txt',
                            delimiter=';',
                            encoding='utf-8',
                            usecols=colunas,
                            low_memory=False)

df_atrac.head(10)
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    IDAtracacao Porto Atracação Tipo da Autoridade Portuária  \
# 0      1303125          Recife             Porto Organizado
# 1      1282509          Recife             Porto Organizado
# 2      1265251           Belém             Porto Organizado
# 3      1282511          Recife             Porto Organizado
# 4      1246116          Recife             Porto Organizado
# 5      1303129          Recife             Porto Organizado
# 6      1282152          Recife             Porto Organizado
# 7      1282153          Recife             Porto Organizado
# 8      1297579          Recife             Porto Organizado
# 9      1261978           Belém             Porto Organizado
#
#         Data Atracação         Data Chegada    Data Desatracação  \
# 0  14/12/2022 09:50:00  14/12/2022 09:25:00  21/12/2022 08:30:00
# 1  09/09/2022 08:55:00  09/09/2022 08:00:00  12/09/2022 10:20:00
# 2  02/08/2022 16:00:00  02/08/2022 15:00:00  05/08/2022 15:01:00
# 3  01/09/2022 13:40:00  01/09/2022 12:50:00  08/09/2022 08:45:00
# 4  21/05/2022 13:10:00  21/05/2022 12:25:00  25/05/2022 18:10:00
# 5  27/12/2022 08:15:00  27/12/2022 07:45:00  29/12/2022 10:30:00
# 6  24/09/2022 07:40:00  24/09/2022 05:30:00  24/09/2022 08:20:00
# 7  23/09/2022 08:22:00  23/09/2022 07:40:00  24/09/2022 09:20:00
# 8  23/11/2022 15:20:00  23/11/2022 14:50:00  30/11/2022 13:50:00
# 9  22/07/2022 05:50:00  22/07/2022 05:50:00  25/07/2022 08:20:00
#
#   Data Início Operação Data Término Operação   Ano  Mes Tipo de Operação  \
# 0                  NaN                   NaN  2022  dez          Marinha
# 1                  NaN                   NaN  2022  set          Marinha
# 2                  NaN                   NaN  2022  ago          Marinha
# 3                  NaN                   NaN  2022  set          Marinha
# 4                  NaN                   NaN  2022  mai          Marinha
# 5                  NaN                   NaN  2022  dez          Marinha
# 6                  NaN                   NaN  2022  set          Marinha
# 7                  NaN                   NaN  2022  set          Marinha
# 8                  NaN                   NaN  2022  nov          Marinha
# 9  22/07/2022 05:51:00   25/07/2022 08:19:00  2022  jul          Marinha
#
#   Município          UF Região Geográfica Região Hidrográfica
# 0    Recife  Pernambuco          Nordeste                 NaN
# 1    Recife  Pernambuco          Nordeste                 NaN
# 2     Belém        Pará             Norte                 NaN
# 3    Recife  Pernambuco          Nordeste                 NaN
# 4    Recife  Pernambuco          Nordeste                 NaN
# 5    Recife  Pernambuco          Nordeste                 NaN
# 6    Recife  Pernambuco          Nordeste                 NaN
# 7    Recife  Pernambuco          Nordeste                 NaN
# 8    Recife  Pernambuco          Nordeste                 NaN
# 9     Belém        Pará             Norte                 NaN

# %%
#NULL
df_atrac.isnull().sum()
# Out:
# IDAtracacao                         0
# Porto Atracação                   116
# Tipo da Autoridade Portuária        0
# Data Atracação                    116
# Data Chegada                      116
# Data Desatracação                   0
# Data Início Operação             4572
# Data Término Operação            4575
# Ano                                 0
# Mes                                 0
# Tipo de Operação                  116
# Município                         116
# UF                                116
# Região Geográfica                 116
# Região Hidrográfica             44463
# dtype: int64

# %%
#QUAIS REGIÕES NO PAIS MAIS TIVERAM ATRACACOES NO ANO DE 2022?

sns.set_theme(style="whitegrid")
atracoes_por_regiao = df_atrac.groupby('Região Geográfica')['Data Atracação'].count().reset_index()
atracoes_por_regiao_sorted = atracoes_por_regiao.sort_values(by='Data Atracação', ascending=True)


plt.figure(figsize=(10, 6))
ax = sns.barplot(
    y=atracoes_por_regiao_sorted['Região Geográfica'],
    x=atracoes_por_regiao_sorted['Data Atracação'],
    palette="Blues_r"
)
for container in ax.containers:
    ax.bar_label(
        container, fmt='%d', fontsize=12, padding=5,
        color='black', weight='bold', label_type="center"
    )

plt.title('Número de Atracações por Região em 2022', fontsize=14, fontweight="bold")
plt.xlabel('Número de Atracações', fontsize=12)
plt.ylabel('Região Geográfica', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-33-592371894>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
#NO NORTE DO PAIS QUAL FOI O ESTADO QUE MAIS TEVE ATRACACAO?


sns.set_theme(style="whitegrid")
df_norte_2022 = pd.read_csv(
    '/content/drive/MyDrive/2022/2022Atracacao.txt',delimiter=';',encoding='utf-8',index_col=0,low_memory=False)

df_norte_2022 = df_norte_2022[
    (df_norte_2022['Ano'] == 2022) &
    (df_norte_2022['Região Geográfica'] == 'Norte')
]

uf_atracacoes = df_norte_2022.groupby('UF')['Data Atracação'].count().reset_index()
uf_atracacoes_sorted = uf_atracacoes.sort_values(by='Data Atracação', ascending=False)
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    x='UF',
    y='Data Atracação',
    data=uf_atracacoes_sorted,
    palette="Blues_r"
)
from matplotlib import font_manager
bold_font = font_manager.FontProperties(weight='bold')
for bar in ax.containers:
    ax.bar_label(
        bar,
        fmt='%d',
        label_type='edge',
        fontsize=10,
        padding=3,
        color="black",
        fontproperties=bold_font
    )
plt.title('Número de Atracações por UF na Região Norte em 2022', fontsize=14, fontweight="bold")
plt.xlabel('UF', fontsize=12)
plt.ylabel('Número de Atracações', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-34-3137013764>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
#NA REGIÃO NORTE ONDE HOUVE MAIS ATRACAÇÕES + RELACIONAR UF E MUNICIPIO:

sns.set_theme(style="whitegrid")
df_atrac = pd.read_csv('/content/drive/MyDrive/2022/2022Atracacao.txt',delimiter=';',encoding='utf-8',index_col=0,low_memory=False)

df_norte_2022 = df_atrac[
    (df_atrac['Ano'] == 2022) &
    (df_atrac['Região Geográfica'] == 'Norte')
]
municipios_p = df_norte_2022.groupby('Município')['Data Atracação'].count().reset_index()
municipios_p_sorted = municipios_p.sort_values(by='Data Atracação', ascending=False).head(10)
palette = sns.color_palette("Blues_r", len(municipios_p_sorted))
plt.figure(figsize=(14, 6))
ax = sns.barplot(
    x='Município',
    y='Data Atracação',
    data=municipios_p_sorted,
    palette=palette
)
from matplotlib import font_manager
bold_font = font_manager.FontProperties(weight='bold')
for bar in ax.containers:
    ax.bar_label(
        bar,
        fmt='%d',
        label_type='edge',
        fontsize=10,
        padding=3,
        color="black",
        fontproperties=bold_font
    )
plt.xticks(rotation=45, ha='right')
plt.title('Municípios com Mais Atracações na Região Norte (2022)', fontsize=14, fontweight="bold")
plt.xlabel('Município', fontsize=12)
plt.ylabel('Número de Atracações', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-2290136833>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
#QUAL É O COMPLEXO PORTUÁRIO NO PARÁ QUE MAIS RECEBEU ATRACAÇAO -> NOME

df_norte = df_norte_2022[df_norte_2022['UF'] == 'Pará']
porto_atrac = df_norte.groupby('Porto Atracação')['Data Atracação'].count().reset_index()
porto_atrac_sorted = porto_atrac.sort_values(by='Data Atracação', ascending=False)
print(porto_atrac_sorted)
# Out:
#                                   Porto Atracação  Data Atracação
# 8                                           Belém            5812
# 22                                       Santarém            4246
# 30     Terminal Portuário Graneleiro de Barcarena            1574
# 36                                  Vila do Conde            1573
# 11                                 ETC Miritituba            1527
# 26                   TUP J F de Oliveira de Belém            1438
# 23                          TUP Bertolini - Belém             958
# 9       Cargill Agrícola S.A. (ETC Miritituba/PA)             748
# 12                    Estação Cianport Miritituba             728
# 24                       TUP Bertolini - Santarém             692
# 14                                      Norte Log             309
# 16                    Petróleo Sabbá - Miritituba             274
# 34                         Terminal Vila do Conde             273
# 32                             Terminal Trombetas             234
# 3   Administração de Bens de Infraestrutura - ABI             201
# 29                     Terminal Ponta da Montanha             152
# 15                      Petróleo Sabbá - Itaituba             121
# 13                 Hidrovias do Brasil Miritituba             121
# 0                                  ABI Miritituba             111
# 28                     Terminal Fluvial de Juruti             104
# 1                                 ATEM Miritituba              93
# 6                       Base de Oriximiná - BARIX              79
# 33                                 Terminal UNI-Z              65
# 10    Companhia Brasileira de Asfalto da Amazônia              42
# 31                 Terminal Saint-Gobain Icoaraci              41
# 20                                 Porto Murucupi              36
# 4                          Base Ipiranga Santarém              32
# 18                                      Porto CRA              26
# 17                                      Porto CPA              26
# 25                                     TUP CESARI              18
# 35                            Terminal de Munguba              15
# 7                Belo Monte Logística de Terminal              12
# 19                  Porto Jari - Terminal Munguba               9
# 21        Porto de Itaituba da Caramuru Alimentos               8
# 5     Base de Distribuição Secundária de Itaituba               6
# 27                        Terminal Fluvial Caulim               6
# 2                                   ATEM Santarém               5

# %%
top_5_portos = pd.DataFrame({
    "Porto Atracação": [
        "Belém", "Santarém", "Terminal Portuário Graneleiro de Barcarena",
        " Vila do Conde", "ETC Miritituba"
    ],
    "Data Atracação": [5812,4246,1574,1573,1527]
})

sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))
ax = sns.barplot(
    x="Data Atracação",
    y="Porto Atracação",
    data=top_5_portos,
    palette="Blues_r"
)

from matplotlib import font_manager
bold_font = font_manager.FontProperties(weight='bold')
for bar in ax.patches:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    ax.text(
        width - 100,
        y,
        f'{int(width)}',
        ha='right',
        va='center',
        fontsize=10,
        color='black',
        fontproperties=bold_font
    )
plt.xlabel("Quantidade de Atracações", fontsize=12)
plt.ylabel("Porto de Atracação", fontsize=12)
plt.title("Top 5 Portos com Mais Atracações no Pará - 2022", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-1696041334>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
# NO SUL QUAL FOI O ESTADO COM MAIS ATRACACOES

df_sul_2022 = df_atrac[(df_atrac['Ano'] == 2022) &
                                    (df_atrac['Região Geográfica'] == 'Sul')]
atracoes_por_uf = df_sul_2022.groupby('UF')['Data Atracação'].count().reset_index()
uf_mais_atracada = atracoes_por_uf.loc[atracoes_por_uf['Data Atracação'].idxmax()]
print(f"O estado com mais atracações na Região Sul em 2022 foi {uf_mais_atracada['UF']} "
      f"com {uf_mais_atracada['Data Atracação']} atracações.")
# Out:
# O estado com mais atracações na Região Sul em 2022 foi Rio Grande do Sul com 7458 atracações.

# %%
#DADOS ESPECÍFICOS DA REGIÃO - NO RS QUAL FOI O MUNICIPIO QUE MAIS RECEBEU ATRACACAO


df_rs = df_sul_2022[df_sul_2022['UF'] == 'Rio Grande do Sul'].copy()
df_rs['Município'] = df_rs['Município'].str.strip().str.upper()
municipios_rs = df_rs.groupby('Município')['Data Atracação'].count().reset_index()
municipios_rs_sorted = municipios_rs.sort_values(by='Data Atracação', ascending=False)
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))
ax = sns.barplot(
    x='Município',
    y='Data Atracação',
    data=municipios_rs_sorted,
    palette="Blues_r"
)

from matplotlib import font_manager
bold_font = font_manager.FontProperties(weight='bold')
for bar in ax.patches:
    height = bar.get_height()
    x = bar.get_x() + bar.get_width() / 2
    ax.text(
        x, height,
        f'{int(height)}',
        ha='center',
        va='bottom',
        fontsize=10,
        color='black',
        fontproperties=bold_font
    )

plt.title('Número de Atracações por Município no Rio Grande do Sul em 2022', fontsize=14, fontweight="bold")
plt.xlabel('Município', fontsize=12)
plt.ylabel('Número de Atracações', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-39-407608276>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
#QUAL É O TIPO DE OPERACAO MAIS COMUM NO SUL

print("----------------------------------------------------------------------------------------------------------------------------------------------------------")
df_atrac =  pd.read_csv('/content/drive/MyDrive/2022/2022Atracacao.txt', delimiter=';', encoding='utf-8', index_col=0, low_memory=False)
valores_unicos = sorted(df_atrac['Tipo de Operação'].dropna().astype(str).unique())
for i, valor in enumerate(valores_unicos, start=1):
    print(f"{i}. {valor}")

print("----------------------------------------------------------------------------------------------------------------------------------------------------------")
df_sul = df_atrac[df_atrac['Região Geográfica'] == 'Sul']
tipo_mais_comum = df_sul['Tipo de Operação'].value_counts()
print(tipo_mais_comum.head(1))
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# 1. Abastecimento
# 2. Apoio
# 3. Marinha
# 4. Misto
# 5. Movimentação da Carga
# 6. Passageiro
# 7. Reparo/Manutenção
# 8. Retirada de Resíduos
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Tipo de Operação
# Movimentação da Carga    10654
# Name: count, dtype: int64

# %%
#EM PARANAGUÁ-PR - QUANTAS ATRACAÇÕES NO ANO DE 2022

file_path = "/content/drive/MyDrive/2022/2022Atracacao.txt"
df_parana = pd.read_csv(file_path, delimiter=";", encoding="utf-8", low_memory=False)
df_parana = df_parana[(df_parana['Ano'] == 2022) &
                                 (df_parana['Município'] == 'Paranaguá')]

num_atracacoes_paranagua = df_parana.shape[0]
print(f"O município de Paranaguá teve {num_atracacoes_paranagua} atracações em 2022.")
# Out:
# O município de Paranaguá teve 2405 atracações em 2022.

# %%
#QUAIS SAO OS TIPOS DE PARALISACOES EXISTENTES

caminho_arquivo = '/content/drive/MyDrive/2022/2022TemposAtracacaoParalisacao.txt'
df_paralis = pd.read_csv(caminho_arquivo, delimiter=';', encoding='utf-8', low_memory=False)
tipos_paralisacoes = sorted(df_paralis["DescricaoTempoDesconto"].dropna().unique())
print("Tipos únicos de paralisações:")
for tipo in tipos_paralisacoes:
    print("-", tipo)
# Out:
# Tipos únicos de paralisações:
# - Acidente
# - Aguardando carga
# - Aguardando sequência de descarga
# - Aguardando transporte rodoviário
# - Aguardando vagões
# - Arqueação
# - Chuva e/ou outras condições climáticas desfavoráveis
# - Falta de energia elétrica
# - Fundeio sem previsão de atracação
# - Greve ou falta de trabalhadores portuários avulsos
# - Liberação de órgãos públicos
# - Limpeza operacional
# - Manobra de embarcação
# - Manutenção preventiva
# - Maré para embarcações com restrição de operação
# - Motivo de segurança
# - Mudança de porão
# - Parada para almoço
# - Peação da carga
# - Pernoite de navio atracado
# - Preparação de equipamentos do cais
# - Problema operacional da embarcação
# - Quebra de equipamento do Operador Portuário, devidamente comprovada
# - Quebra de equipamento do Porto, devidamente comprovada
# - Rechego
# - Sem operação por conveniência do agente
# - Sem operação por conveniência do armador
# - Sem operação por conveniência do operador
# - Troca de turno

# %%
#PARALISACAO PORTO DE PARANAGUÁ - CALCULAR AS HORAS PERDIDAS ENTRE O INICIO E TERMINO DA PARALISACAO - EU USO O ARQUIVO DF_PARALIS

df_atrac= pd.read_csv('/content/drive/MyDrive/2022/2022Atracacao.txt', delimiter=';', encoding='utf-8', low_memory=False)
df_tempos = pd.read_csv('/content/drive/MyDrive/2022/2022TemposAtracacao.txt', delimiter=';', encoding='utf-8', low_memory=False)
df_paraliS = pd.read_csv('/content/drive/MyDrive/2022/2022TemposAtracacaoParalisacao.txt', delimiter=';', encoding='utf-8', low_memory=False)

# %%
#HORAS PERDIDAS NAS PARALISACOES
df_paralis['DTInicio'] = pd.to_datetime(df_paralis['DTInicio'], dayfirst=True)
df_paralis['DTTermino'] = pd.to_datetime(df_paralis['DTTermino'], dayfirst=True)
df_paralis['Horas Perdidas'] = (df_paralis['DTTermino'] - df_paralis['DTInicio']).dt.total_seconds() / 3600

# %%
#DADOS SOMENTE DE PARANAGUÁ

df_atrac2022_paranagua = df_atrac[df_atrac['Porto Atracação'] == 'Paranaguá']
df_paralis_paranagua = df_paralis[df_paralis['IDAtracacao'].isin(df_atrac2022_paranagua['IDAtracacao'])]
df_merged = df_paralis_paranagua.merge(
    df_atrac2022_paranagua[['IDAtracacao', 'Data Atracação', 'Data Chegada', 'Data Desatracação', 'Data Início Operação', 'Data Término Operação']],
    on='IDAtracacao',
    how='left'
)
df_merged.head()
# Out:
#    IDTemposDescontos  IDAtracacao  \
# 0             743064      1215983
# 1             743065      1215983
# 2             743066      1215983
# 3             743067      1215983
# 4             743068      1215983
#
#                               DescricaoTempoDesconto            DTInicio  \
# 0  Chuva e/ou outras condições climáticas desfavo... 2022-01-08 03:49:00
# 1    Maré para embarcações com restrição de operação 2022-01-09 13:00:00
# 2  Quebra de equipamento do Porto, devidamente co... 2022-01-08 05:01:00
# 3  Chuva e/ou outras condições climáticas desfavo... 2022-01-08 06:32:00
# 4  Chuva e/ou outras condições climáticas desfavo... 2022-01-08 07:00:00
#
#             DTTermino  Horas Perdidas       Data Atracação  \
# 0 2022-01-08 04:01:00        0.200000  31/12/2021 11:36:00
# 1 2022-01-09 15:14:00        2.233333  31/12/2021 11:36:00
# 2 2022-01-08 05:32:00        0.516667  31/12/2021 11:36:00
# 3 2022-01-08 07:00:00        0.466667  31/12/2021 11:36:00
# 4 2022-01-08 07:49:00        0.816667  31/12/2021 11:36:00
#
#           Data Chegada    Data Desatracação Data Início Operação  \
# 0  28/12/2021 04:42:00  09/01/2022 15:15:00  31/12/2021 20:21:00
# 1  28/12/2021 04:42:00  09/01/2022 15:15:00  31/12/2021 20:21:00
# 2  28/12/2021 04:42:00  09/01/2022 15:15:00  31/12/2021 20:21:00
# 3  28/12/2021 04:42:00  09/01/2022 15:15:00  31/12/2021 20:21:00
# 4  28/12/2021 04:42:00  09/01/2022 15:15:00  31/12/2021 20:21:00
#
#   Data Término Operação
# 0   09/01/2022 13:00:00
# 1   09/01/2022 13:00:00
# 2   09/01/2022 13:00:00
# 3   09/01/2022 13:00:00
# 4   09/01/2022 13:00:00

# %%
#JUNÇAO DOS DADOS - PARANAGUÁ

resumo = df_merged.groupby('IDAtracacao').agg({
    'Horas Perdidas': ['count', 'sum', 'mean'],
    'Data Término Operação': 'first'
}).reset_index()

resumo.columns = ['IDAtracacao', 'paralisacoes', 'total_paralisacao', 'media_paralisacao', 'tempo_otimo']
resumo.head()
# Out:
#    IDAtracacao  paralisacoes  total_paralisacao  media_paralisacao  \
# 0      1213300            69          88.650000           1.284783
# 1      1214884            96         103.433333           1.077431
# 2      1214885            55          57.550000           1.046364
# 3      1214889            89         181.583333           2.040262
# 4      1214890           110         186.150000           1.692273
#
#            tempo_otimo
# 0  02/01/2022 14:45:00
# 1  04/01/2022 02:12:00
# 2  08/01/2022 10:15:00
# 3  03/01/2022 06:15:00
# 4  03/01/2022 18:50:00

# %%
#QUANTAS VEZES CADA PARALISACAO OCORREU E HORAS TOTAIS

ocorrencias = df_paralis_paranagua.groupby('DescricaoTempoDesconto')['Horas Perdidas'].agg(['count', 'sum']).reset_index()
ocorrencias.columns = ['motivo', 'ocorrencias', 'horas_perdidas']
ocorrencias = ocorrencias.sort_values(by='horas_perdidas', ascending=False)
ocorrencias.head()
# Out:
#                                               motivo  ocorrencias  \
# 2  Chuva e/ou outras condições climáticas desfavo...        12600
# 7    Maré para embarcações com restrição de operação         5257
# 5                       Liberação de órgãos públicos         1291
# 0                   Aguardando transporte rodoviário        13650
# 8                                   Mudança de porão        15349
#
#    horas_perdidas
# 2    32479.816667
# 7     8859.383333
# 5     5382.150000
# 0     5167.933333
# 8     4279.783333

# %%
#MOTIVO MAIS COMUM EM PARANAGUÁ

df_paranagua = df_paralis.merge(df_atrac[['IDAtracacao', 'Porto Atracação']],on='IDAtracacao',how='left')
df_paranagua = df_paranagua[df_paranagua['Porto Atracação'] == 'Paranaguá']

motivos = df_paranagua.groupby('DescricaoTempoDesconto')['Horas Perdidas'].sum().reset_index()
motivos_sorted = motivos.sort_values(by='Horas Perdidas', ascending=False)
motivo_mais_comum = motivos_sorted.iloc[0]
print("Motivo mais comum de paralisação em Paranaguá:")
print(motivo_mais_comum)
# Out:
# Motivo mais comum de paralisação em Paranaguá:
# DescricaoTempoDesconto    Chuva e/ou outras condições climáticas desfavo...
# Horas Perdidas                                                 32479.816667
# Name: 2, dtype: object

# %%
#OS PRINCIPAIS MOTIVOS DE PARALISACAO EM PARANAGUA E O VALOR DE HORAS OCORRIDO

sns.set(style="whitegrid")
ocorrencias_sorted = ocorrencias.sort_values('horas_perdidas', ascending=False)


plt.figure(figsize=(19, 6))
barplot = sns.barplot(
    data=ocorrencias_sorted,
    y='motivo',
    x='horas_perdidas',
    palette='Blues_d'
)
for bar in barplot.patches:
    width = bar.get_width()
    plt.text(width + 300,
             bar.get_y() + bar.get_height() / 2,
             f'{width:,.0f}',
             va='center',
             fontsize=9)

plt.title('Tipos de Paralisação - Todas as Atracações (Paranaguá)', fontsize=12, fontweight='bold')
plt.suptitle('Horas em todos os berços e atracações (2022: Jan - Dez)', fontsize=10)
plt.xlabel('Total de horas')
plt.ylabel('Tipos de Paralisação')
plt.grid(axis='x', linestyle='--', linewidth=0.8, alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-49-1697262993>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
#PARALISACAO POR REGIÃO GEOGRAFICA - HORAS


df_paralisado = df_paralis.merge(df_atrac[['IDAtracacao', 'Região Geográfica']],on='IDAtracacao',how='left')
agrupado = df_paralisado.groupby(['Região Geográfica', 'DescricaoTempoDesconto'])['Horas Perdidas'].sum().reset_index()
top_por_regiao = agrupado.sort_values(['Região Geográfica', 'Horas Perdidas'],ascending=[True, False]).groupby('Região Geográfica').first().reset_index()

print(top_por_regiao)
plt.figure(figsize=(14, 6))
barplot = sns.barplot(
    data=top_por_regiao,
    x='Horas Perdidas',
    y='Região Geográfica',
    hue='DescricaoTempoDesconto',
    palette='Blues_d'
)

for bar in barplot.patches:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    if width > 0:
        plt.text(
            width + 500,
            y,
            f'{width:,.0f}',
            va='center',
            fontsize=9
        )
plt.title('Motivo de Paralisação Mais Comum por Região Geográfica (2022)', fontsize=14, weight='bold')
plt.xlabel('Horas Perdidas')
plt.ylabel('Região Geográfica')
plt.legend(
    title='Motivo de Paralisação',
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    frameon=False
)
plt.tight_layout()
plt.show()
# Out:
#   Região Geográfica                             DescricaoTempoDesconto  \
# 0          Nordeste  Chuva e/ou outras condições climáticas desfavo...
# 1             Norte                 Problema operacional da embarcação
# 2           Sudeste                  Fundeio sem previsão de atracação
# 3               Sul  Chuva e/ou outras condições climáticas desfavo...
#
#    Horas Perdidas
# 0     4538.783333
# 1     5836.816667
# 2    15099.300000
# 3    46528.566667

# %%
#TIPO MAIS COMUM NO PORTO DE RIO GRANDE(RS), SAO FRANCISCO DO SUL(SC), E PARANAGUA(PR) - HORAS

sns.set(style="whitegrid")
df_portos = df_paralis.merge(df_atrac[['IDAtracacao', 'Porto Atracação']],on='IDAtracacao',how='left')


portos_alvo = ['Paranaguá', 'São Francisco do Sul', 'Rio Grande']
df_filtrado = df_portos[df_portos['Porto Atracação'].isin(portos_alvo)]
agrupado = df_filtrado.groupby(['Porto Atracação', 'DescricaoTempoDesconto'])['Horas Perdidas'].sum().reset_index()

top_motivos = agrupado.sort_values(['Porto Atracação', 'Horas Perdidas'], ascending=[True, False])
top_por_porto = top_motivos.groupby('Porto Atracação').first().reset_index()
top_por_porto_sorted = top_por_porto.sort_values('Horas Perdidas', ascending=True)


plt.figure(figsize=(18, 6))
barplot = sns.barplot(
    data=top_por_porto_sorted,
    x='Horas Perdidas',
    y='Porto Atracação',
    palette='Blues_d'
)
for bar in barplot.patches:
    width = bar.get_width()
    plt.text(width + 200,
             bar.get_y() + bar.get_height() / 2,
             f'{width:,.0f}',
             va='center')
plt.title("Motivo Mais Comum de Paralisação por Porto (2022)", fontsize=14, weight='bold')
plt.xlabel("Horas Perdidas")
plt.ylabel("Porto")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-51-946074402>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
#ESTADO DO SUL QUE MAIS TEM PARALISACAO - HORAS aqui incluiu porto de Antonina

df_paralisado = df_paralis.merge(df_atrac[['IDAtracacao', 'Região Geográfica', 'UF']],on='IDAtracacao', how='left')
df_sul = df_paralisado[df_paralisado['Região Geográfica'] == 'Sul']
paralisacao_por_estado = df_sul.groupby('UF')['Horas Perdidas'].sum().reset_index()
paralisacao_por_estado = paralisacao_por_estado.sort_values(by='Horas Perdidas', ascending=False)

print(paralisacao_por_estado)

print('---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')

plt.figure(figsize=(14, 5))
ax = sns.barplot(
    data=paralisacao_por_estado,
    x='Horas Perdidas',
    y='UF',
    palette='Blues_d'
)
for bar in ax.patches:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 300,
        y,
        f'{width:,.0f}',
        va='center',
        fontsize=9
    )

plt.title('Total de Horas de Paralisação por Estado da Região Sul (2022)', fontsize=13, weight='bold')
plt.xlabel('Horas Perdidas')
plt.ylabel('Estado')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

print('----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')


labels = paralisacao_por_estado['UF']
sizes = paralisacao_por_estado['Horas Perdidas']
colors = sns.color_palette('Blues', len(labels))
plt.figure(figsize=(8, 8))
plt.pie(
    sizes,
    labels=labels,
    colors=colors,
    autopct='%1.1f%%',
    startangle=140,
    wedgeprops={'edgecolor': 'black'}
)

plt.title('Distribuição das Horas de Paralisação por Estado (Região Sul - 2022)', fontsize=14, weight='bold')
plt.tight_layout()
plt.show()
# Out:
#                   UF  Horas Perdidas
# 0             Paraná    73108.733333
# 2     Santa Catarina    11036.866667
# 1  Rio Grande do Sul     5969.600000
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# <ipython-input-52-1270746109>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#PORTOS NA REGIÃO SUL COM MAIOR NÚMERO DE HORAS EM PARALISAÇÃO


df_paralisado = df_paralis.merge(df_atrac[['IDAtracacao', 'Região Geográfica', 'Porto Atracação']], on='IDAtracacao',how='left')
df_sul = df_paralisado[df_paralisado['Região Geográfica'] == 'Sul']
top_instalacoes = df_sul.groupby('Porto Atracação')['Horas Perdidas'].sum().reset_index()
top_instalacoes = top_instalacoes.sort_values(by='Horas Perdidas', ascending=False).head(5)
print(top_instalacoes)

print('----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')


plt.figure(figsize=(13, 6))
ax = sns.barplot(
    data=top_instalacoes,
    y='Porto Atracação',
    x='Horas Perdidas',
    palette='Blues_d'
)

for bar in ax.patches:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 300,
        y,
        f'{width:,.0f}',
        va='center',
        fontsize=9
    )
plt.title('Top 5 Instalações com Mais Horas de Paralisação na Região Sul (2022)', fontsize=14, weight='bold')
plt.xlabel('Horas Perdidas')
plt.ylabel('Instalação Portuária')
plt.tight_layout()
plt.show()
# Out:
#          Porto Atracação  Horas Perdidas
# 6              Paranaguá    67660.583333
# 0               Antonina     5448.150000
# 2               Imbituba     5181.983333
# 10  São Francisco do Sul     4719.266667
# 9             Rio Grande     3066.150000
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# <ipython-input-53-370838047>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
#OS 10 MAIORES  PORTOS EM PARALISACAO POR HORAS EM TODAS AS REGIOES GEOGRAFICAS


df_paralisado = df_paralis.merge(df_atrac[['IDAtracacao', 'Porto Atracação', 'UF', 'Região Geográfica']], on='IDAtracacao',how='left')
top_10_portos = df_paralisado.groupby(['Porto Atracação', 'UF', 'Região Geográfica'])['Horas Perdidas'].sum().reset_index()
top_10_portos = top_10_portos.sort_values(by='Horas Perdidas', ascending=False).head(10)
print(top_10_portos.to_string(index=False))

print('-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')

plt.figure(figsize=(19, 6))
ax = sns.barplot(
    data=top_10_portos,
    y='Porto Atracação',
    x='Horas Perdidas',
    palette='Blues_d'
)
for bar in ax.patches:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(
        width + 500,
        y,
        f'{width:,.0f}',
        va='center',
        fontsize=9
    )
plt.title('Top 10 Portos com Mais Horas de Paralisação no Brasil (2022)', fontsize=14, weight='bold')
plt.xlabel('Horas Perdidas')
plt.ylabel('Porto de Atracação')
plt.tight_layout()
plt.show()
# Out:
#                                          Porto Atracação                  UF Região Geográfica  Horas Perdidas
#                                                Paranaguá              Paraná               Sul    67660.583333
# Terminal Aquaviário de São Sebastião (Almirante Barroso)           São Paulo           Sudeste    10582.816667
#                                                 Santarém                Pará             Norte     6740.416667
#                                                 Antonina              Paraná               Sul     5448.150000
#                                                 Imbituba      Santa Catarina               Sul     5181.983333
#                                     São Francisco do Sul      Santa Catarina               Sul     4719.266667
#                                                  Niterói      Rio de Janeiro           Sudeste     4416.450000
#                                                    Suape          Pernambuco          Nordeste     3694.433333
#                                               Rio Grande   Rio Grande do Sul               Sul     3066.150000
#                                             Areia Branca Rio Grande do Norte          Nordeste     3014.183333
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# <ipython-input-54-3155668663>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
#CONFERENCIA DE IDS

df_paralis = pd.read_csv('/content/drive/MyDrive/2022/2022TemposAtracacaoParalisacao.txt',sep=';', encoding='utf-8', low_memory=False)
print(df_paralis[['IDAtracacao', 'DescricaoTempoDesconto']].head())
paralisacoes_por_id = df_paralis.groupby('IDAtracacao')['DescricaoTempoDesconto'].nunique().reset_index()
paralisacoes_por_id.columns = ['IDATRACACAO', 'TIPOS_PARALISACAO_UNICOS']

print("\nParalisações únicas por ID:")
print(paralisacoes_por_id.head())

id_exemplo = 1049680
df_id = df_paralis[df_paralis['IDAtracacao'] == id_exemplo]


coluna_tipo = 'TIPOPARALISACAO' if 'TIPOPARALISACAO' in df_id.columns else 'DescricaoTempoDesconto'
tipos = df_id[coluna_tipo].unique()
print(f"\nO ID {id_exemplo} teve {len(tipos)} tipos de paralisação:")
print(tipos)
# Out:
#    IDAtracacao                             DescricaoTempoDesconto
# 0      1215901                              Manobra de embarcação
# 1      1215970  Chuva e/ou outras condições climáticas desfavo...
# 2      1215983  Chuva e/ou outras condições climáticas desfavo...
# 3      1215983    Maré para embarcações com restrição de operação
# 4      1215983  Quebra de equipamento do Porto, devidamente co...
#
# Paralisações únicas por ID:
#    IDATRACACAO  TIPOS_PARALISACAO_UNICOS
# 0      1207135                         1
# 1      1207266                         1
# 2      1207400                         1
# 3      1208397                         1
# 4      1208458                         1
#
# O ID 1049680 teve 0 tipos de paralisação:
# []

# %%
#OS 10 ID's MAIS PARALISACOES

frequencia_ids = df_paralis['IDAtracacao'].value_counts().reset_index()
frequencia_ids.columns = ['IDATRACACAO', 'TOTAL_REGISTROS']

print("Top 10 IDATRACACAO com mais registros:")
print(frequencia_ids.head(10))


frequencia_ids = df_paralis['IDAtracacao'].value_counts().reset_index()
frequencia_ids.columns = ['IDATRACACAO', 'TOTAL_REGISTROS']
top_ids = frequencia_ids.head(10)['IDATRACACAO'].tolist()
print("\nTipos de paralisação para os 10 IDs com mais registros:\n")

for id_exemplo in top_ids:
    df_id = df_paralis[df_paralis['IDAtracacao'] == id_exemplo]
    coluna_tipo = 'TIPOPARALISACAO' if 'TIPOPARALISACAO' in df_id.columns else 'DescricaoTempoDesconto'
    tipos = df_id[coluna_tipo].unique()
    print(f"ID {id_exemplo} teve {len(tipos)} tipos de paralisação:")
    print(tipos)
    print("-" * 60)
# Out:
# Top 10 IDATRACACAO com mais registros:
#    IDATRACACAO  TOTAL_REGISTROS
# 0      1275916              385
# 1      1245894              296
# 2      1284354              290
# 3      1285041              274
# 4      1289594              230
# 5      1304583              215
# 6      1278746              214
# 7      1292919              212
# 8      1246105              211
# 9      1297238              209
#
# Tipos de paralisação para os 10 IDs com mais registros:
#
# ID 1275916 teve 7 tipos de paralisação:
# ['Aguardando transporte rodoviário' 'Mudança de porão'
#  'Quebra de equipamento do Operador Portuário, devidamente comprovada'
#  'Troca de turno' 'Chuva e/ou outras condições climáticas desfavoráveis'
#  'Maré para embarcações com restrição de operação'
#  'Liberação de órgãos públicos']
# ------------------------------------------------------------
# ID 1245894 teve 7 tipos de paralisação:
# ['Maré para embarcações com restrição de operação' 'Troca de turno'
#  'Mudança de porão' 'Aguardando transporte rodoviário'
#  'Chuva e/ou outras condições climáticas desfavoráveis'
#  'Liberação de órgãos públicos'
#  'Quebra de equipamento do Operador Portuário, devidamente comprovada']
# ------------------------------------------------------------
# ID 1284354 teve 10 tipos de paralisação:
# ['Troca de turno'
#  'Quebra de equipamento do Operador Portuário, devidamente comprovada'
#  'Aguardando transporte rodoviário' 'Mudança de porão'
#  'Maré para embarcações com restrição de operação'
#  'Quebra de equipamento do Porto, devidamente comprovada'
#  'Liberação de órgãos públicos' 'Limpeza operacional'
#  'Chuva e/ou outras condições climáticas desfavoráveis' 'Rechego']
# ------------------------------------------------------------
# ID 1285041 teve 8 tipos de paralisação:
# ['Maré para embarcações com restrição de operação'
#  'Liberação de órgãos públicos' 'Mudança de porão'
#  'Aguardando transporte rodoviário' 'Troca de turno'
#  'Chuva e/ou outras condições climáticas desfavoráveis'
#  'Falta de energia elétrica'
#  'Quebra de equipamento do Porto, devidamente comprovada']
# ------------------------------------------------------------
# ID 1289594 teve 9 tipos de paralisação:
# ['Mudança de porão' 'Aguardando transporte rodoviário'
#  'Chuva e/ou outras condições climáticas desfavoráveis'
#  'Quebra de equipamento do Porto, devidamente comprovada'
#  'Quebra de equipamento do Operador Portuário, devidamente comprovada'
#  'Falta de energia elétrica'
#  'Maré para embarcações com restrição de operação' 'Troca de turno'
#  'Liberação de órgãos públicos']
# ------------------------------------------------------------
# ID 1304583 teve 5 tipos de paralisação:
# ['Troca de turno' 'Aguardando transporte rodoviário' 'Aguardando carga'
#  'Mudança de porão' 'Chuva e/ou outras condições climáticas desfavoráveis']
# ------------------------------------------------------------
# ID 1278746 teve 10 tipos de paralisação:
# ['Maré para embarcações com restrição de operação' 'Mudança de porão'
#  'Aguardando transporte rodoviário' 'Troca de turno'
#  'Chuva e/ou outras condições climáticas desfavoráveis'
#  'Falta de energia elétrica'
#  'Quebra de equipamento do Porto, devidamente comprovada'
#  'Liberação de órgãos públicos' 'Rechego'
#  'Quebra de equipamento do Operador Portuário, devidamente comprovada']
# ------------------------------------------------------------
# ID 1292919 teve 6 tipos de paralisação:
# ['Chuva e/ou outras condições climáticas desfavoráveis'
#  'Liberação de órgãos públicos' 'Mudança de porão'
#  'Aguardando transporte rodoviário' 'Troca de turno'
#  'Maré para embarcações com restrição de operação']
# ------------------------------------------------------------
# ID 1246105 teve 9 tipos de paralisação:
# ['Mudança de porão' 'Aguardando transporte rodoviário'
#  'Chuva e/ou outras condições climáticas desfavoráveis'
#  'Quebra de equipamento do Porto, devidamente comprovada'
#  'Quebra de equipamento do Operador Portuário, devidamente comprovada'
#  'Falta de energia elétrica'
#  'Maré para embarcações com restrição de operação' 'Troca de turno'
#  'Limpeza operacional']
# ------------------------------------------------------------
# ID 1297238 teve 11 tipos de paralisação:
# ['Maré para embarcações com restrição de operação' 'Mudança de porão'
#  'Limpeza operacional' 'Aguardando transporte rodoviário'
#  'Quebra de equipamento do Operador Portuário, devidamente comprovada'
#  'Chuva e/ou outras condições climáticas desfavoráveis' 'Troca de turno'
#  'Quebra de equipamento do Porto, devidamente comprovada'
#  'Liberação de órgãos públicos' 'Falta de energia elétrica' 'Rechego']
# ------------------------------------------------------------
